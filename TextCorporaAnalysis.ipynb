# %%
import nltk
from nltk.corpus import genesis

# %%
genesis.fileids()
# Out:
# ['english-kjv.txt',
#  'english-web.txt',
#  'finnish.txt',
#  'french.txt',
#  'german.txt',
#  'lolcat.txt',
#  'portuguese.txt',
#  'swedish.txt']

# %%
for fileid in genesis.fileids():
    n_chars = len(genesis.raw(fileid))
    n_words = len(genesis.words(fileid))
    n_sents = len(genesis.sents(fileid))
    print(int(n_chars/n_words), int(n_words/n_sents), fileid)
# Out:
# 4 30 english-kjv.txt
# 4 19 english-web.txt
# 5 15 finnish.txt
# 4 23 french.txt
# 4 23 german.txt
# 4 20 lolcat.txt
# 4 27 portuguese.txt
# 4 30 swedish.txt

# %%
from nltk.corpus import PlaintextCorpusReader

# %%
corpus_root = '/usr/share/dict'

# %%
wordlists = PlaintextCorpusReader(corpus_root, '.*')

# %%
wordlists.fileids()
# Out:
# ['README', 'connectives', 'propernames', 'web2', 'web2a', 'words']

# %%
items = ['apple', 'apple', 'kiwi', 'cabbage', 'cabbage', 'potato']

# %%
freq = nltk.FreqDist(items)
freq
# Out:
# FreqDist({'apple': 2, 'cabbage': 2, 'kiwi': 1, 'potato': 1})

# %%
freq.plot(cumulative = True)

# %%
c_items = [('F','apple'), ('F','apple'), ('F','kiwi'), ('V','cabbage'), ('V','cabbage'), ('V','potato') ]

# %%
cfd = nltk.ConditionalFreqDist(c_items)

# %%
cfd.conditions()
# Out:
# ['F', 'V']

# %%
cfd['V']
# Out:
# FreqDist({'cabbage': 2, 'potato': 1})

# %%
cfd['F']
# Out:
# FreqDist({'apple': 2, 'kiwi': 1})

# %%
cfd.plot()

# %%
from nltk.corpus import brown

# %%
cfd = nltk.ConditionalFreqDist([ 
(genre, word) 
for genre in brown.categories() 
for word in brown.words(categories=genre) ])

# %%
cfd.conditions()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
news_fd = cfd['news']
news_fd.items()
# Out:
# dict_items([('The', 806), ('Fulton', 14), ('County', 35), ('Grand', 6), ('Jury', 2), ('said', 402), ('Friday', 41), ('an', 300), ('investigation', 9), ('of', 2849), ("Atlanta's", 4), ('recent', 20), ('primary', 17), ('election', 38), ('produced', 6), ('``', 732), ('no', 109), ('evidence', 17), ("''", 702), ('that', 802), ('any', 90), ('irregularities', 3), ('took', 47), ('place', 25), ('.', 4030), ('jury', 44), ('further', 16), ('in', 1893), ('term-end', 1), ('presentments', 1), ('the', 5580), ('City', 44), ('Executive', 6), ('Committee', 37), (',', 5188), ('which', 244), ('had', 279), ('over-all', 2), ('charge', 17), ('deserves', 3), ('praise', 2), ('and', 2146), ('thanks', 6), ('Atlanta', 14), ('for', 943), ('manner', 7), ('was', 717), ('conducted', 8), ('September-October', 1), ('term', 13), ('been', 212), ('charged', 12), ('by', 497), ('Superior', 5), ('Court', 26), ('Judge', 28), ('Durwood', 1), ('Pye', 1), ('to', 2116), ('investigate', 3), ('reports', 12), ('possible', 28), ('hard-fought', 1), ('won', 24), ('Mayor-nominate', 1), ('Ivan', 2), ('Allen', 7), ('Jr.', 46), ('Only', 8), ('a', 1993), ('relative', 3), ('handful', 1), ('such', 70), ('received', 33), ('considering', 2), ('widespread', 4), ('interest', 32), ('number', 32), ('voters', 12), ('size', 8), ('this', 250), ('city', 49), ('it', 363), ('did', 63), ('find', 16), ('many', 60), ("Georgia's", 7), ('registration', 2), ('laws', 30), ('are', 328), ('outmoded', 1), ('or', 173), ('inadequate', 4), ('often', 14), ('ambiguous', 1), ('It', 115), ('recommended', 9), ('legislators', 8), ('act', 20), ('have', 265), ('these', 59), ('studied', 7), ('revised', 2), ('end', 29), ('modernizing', 1), ('improving', 4), ('them', 96), ('grand', 13), ('commented', 7), ('on', 657), ('other', 149), ('topics', 2), ('among', 24), ('purchasing', 3), ('departments', 2), ('well', 43), ('operated', 4), ('follow', 12), ('generally', 14), ('accepted', 4), ('practices', 7), ('inure', 1), ('best', 29), ('both', 56), ('governments', 5), ('Merger', 1), ('proposed', 18), ('However', 12), ('believes', 8), ('two', 157), ('offices', 4), ('should', 59), ('be', 526), ('combined', 9), ('achieve', 6), ('greater', 10), ('efficiency', 2), ('reduce', 8), ('cost', 15), ('administration', 52), ('Purchasing', 1), ('Department', 20), ('is', 732), ('lacking', 3), ('experienced', 4), ('clerical', 4), ('personnel', 11), ('as', 481), ('result', 30), ('policies', 8), ('urged', 11), ('take', 48), ('steps', 8), ('remedy', 1), ('problem', 39), ('Implementation', 1), ('automobile', 4), ('title', 3), ('law', 38), ('also', 120), ('outgoing', 3), ('next', 40), ('Legislature', 19), ('provide', 24), ('enabling', 5), ('funds', 28), ('re-set', 1), ('effective', 15), ('date', 16), ('so', 67), ('orderly', 3), ('implementation', 1), ('may', 66), ('effected', 1), ('swipe', 1), ('at', 598), ('State', 63), ('Welfare', 3), ("Department's", 2), ('handling', 3), ('federal', 35), ('granted', 5), ('child', 9), ('welfare', 13), ('services', 18), ('foster', 1), ('homes', 9), ('This', 70), ('one', 184), ('major', 28), ('items', 4), ('general', 29), ('assistance', 8), ('program', 66), ('but', 174), ('has', 300), ('seen', 7), ('fit', 3), ('distribute', 2), ('through', 54), ('all', 163), ('counties', 13), ('state', 90), ('with', 545), ('exception', 4), ('receives', 1), ('none', 7), ('money', 29), ('jurors', 4), ('they', 205), ('realize', 4), ('proportionate', 1), ('distribution', 7), ('might', 38), ('disable', 1), ('our', 55), ('less', 10), ('populous', 3), ('Nevertheless', 1), ('we', 77), ('feel', 19), ('future', 25), ('receive', 15), ('some', 95), ('portion', 2), ('available', 10), ('Failure', 2), ('do', 63), ('will', 389), ('continue', 11), ('disproportionate', 1), ('burden', 2), ('taxpayers', 5), ("ordinary's", 1), ('court', 29), ('under', 83), ('fire', 21), ('its', 174), ('appointment', 8), ('appraisers', 1), ('guardians', 2), ('administrators', 1), ('awarding', 1), ('fees', 13), ('compensation', 4), ('Wards', 1), ('protected', 1), ('foun ...

# %%
news_fd.most_common(3)
# Out:
# [('the', 5580), (',', 5188), ('.', 4030)]

# %%
news_fd['the']
# Out:
# 5580

# %%
from nltk.corpus import names
nt = [(fid.split('.')[0], name[-1])    for fid in names.fileids() 
  for name in names.words(fid) ]
cfd2 = nltk.ConditionalFreqDist(nt)
cfd2['female'] > cfd2['male']
# Out:
# True

# %%
type(cfd2.tabulate(samples=['a', 'e']))
# Out:
#           a    e
# female 1773 1432
#   male   29  468
# NoneType

# %%
from nltk.corpus import reuters

# %%
cfd_1=nltk.ConditionalFreqDist([ 
(genre, word) 
for genre in reuters.categories() 
for word in reuters.words(categories=genre) ])

# %%
cfd_1.conditions()
# Out:
# ['acq',
#  'alum',
#  'barley',
#  'bop',
#  'carcass',
#  'castor-oil',
#  'cocoa',
#  'coconut',
#  'coconut-oil',
#  'coffee',
#  'copper',
#  'copra-cake',
#  'corn',
#  'cotton',
#  'cotton-oil',
#  'cpi',
#  'cpu',
#  'crude',
#  'dfl',
#  'dlr',
#  'dmk',
#  'earn',
#  'fuel',
#  'gas',
#  'gnp',
#  'gold',
#  'grain',
#  'groundnut',
#  'groundnut-oil',
#  'heat',
#  'hog',
#  'housing',
#  'income',
#  'instal-debt',
#  'interest',
#  'ipi',
#  'iron-steel',
#  'jet',
#  'jobs',
#  'l-cattle',
#  'lead',
#  'lei',
#  'lin-oil',
#  'livestock',
#  'lumber',
#  'meal-feed',
#  'money-fx',
#  'money-supply',
#  'naphtha',
#  'nat-gas',
#  'nickel',
#  'nkr',
#  'nzdlr',
#  'oat',
#  'oilseed',
#  'orange',
#  'palladium',
#  'palm-oil',
#  'palmkernel',
#  'pet-chem',
#  'platinum',
#  'potato',
#  'propane',
#  'rand',
#  'rape-oil',
#  'rapeseed',
#  'reserves',
#  'retail',
#  'rice',
#  'rubber',
#  'rye',
#  'ship',
#  'silver',
#  'sorghum',
#  'soy-meal',
#  'soy-oil',
#  'soybean',
#  'strategic-metal',
#  'sugar',
#  'sun-meal',
#  'sun-oil',
#  'sunseed',
#  'tea',
#  'tin',
#  'trade',
#  'veg-oil',
#  'wheat',
#  'wpi',
#  'yen',
#  'zinc']

# %%
cfd_1['sugar']['sugar']
# Out:
# 521
