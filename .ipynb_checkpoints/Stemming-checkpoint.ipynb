# %% [markdown]
# # Stemming

# %% [markdown]
# - Stemming is a process of stripping affixes from words.
# example:
# input - Natural language processing in python
#          output - Natur Languag process in pyton

# %% [markdown]
# - More often, you normalize text by converting all the words into lowercase. This will treat both words The and the as same.
#
# - With stemming, the words playing, played and play will be treated as single word, i.e. play.

# %% [markdown]
# # Stemmers in nltk

# %% [markdown]
# - nltk comes with few stemmers.
#
# - The two widely used stemmers are Porter and Lancaster stemmers.
#
# - These stemmers have their own rules for string affixes.
#
# - The following example demonstrates stemming of word builders using PorterStemmer.

# %%
import nltk
from nltk import PorterStemmer,LancasterStemmer

# %%
porter = nltk.PorterStemmer()

# %%
porter.stem('builders')
# Out:
# 'builder'

# %%
porter.stem('played')
# Out:
# 'play'

# %% [markdown]
# - Now let's see how to use LancasterStemmer and stem the word builders.

# %%
lancaster = LancasterStemmer()

# %%
lancaster.stem('builders')
# Out:
# 'build'

# %% [markdown]
# - Lancaster Stemmer returns build whereas Porter Stemmer returns builder.

# %% [markdown]
# # Normalizing with Stemming
# - Let's consider the text collection, text1.
#
# - Let's first determine the number of unique words present in original text1.
#
# - Then normalize the text by converting all the words into lower case and again determine the number of unique words.

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
len(set(text1))
# Out:
# 19317

# %%
lc_words = [ word.lower() for word in text1]

# %%
len(set(lc_words))
# Out:
# 17231

# %% [markdown]
# - Now let's further normalize text1 with Porter Stemmer.

# %%
p_stem_words = [porter.stem(word) for word in set(lc_words) ]

# %%
len(set(p_stem_words))
# Out:
# 10927

# %% [markdown]
# - The above output shows that, after normalising with Porter Stemmer, the text1 collection has 10927 unique words.

# %%
l_stem_words = [lancaster.stem(word) for word in set(lc_words) ]

# %%
len(set(l_stem_words))
# Out:
# 9036

# %% [markdown]
# - Applying Lancaster Stemmer to text1 collection resulted in 9036 words.

# %% [markdown]
# # Understanding Lemma
# - Lemma is a lexical entry in a lexical resource such as word dictionary.
#
# - You can find multiple Lemma's with the same spelling. These are known as homonyms.
#
# - For example, consider the two Lemma's listed below, which are homonyms.
#
# 1. saw [verb] - Past tense of see
# 2. saw [noun] - Cutting instrument

# %% [markdown]
# # Lemmatization
# - nltk comes with WordNetLemmatizer. This lemmatizer removes affixes only if the resulting word is found in lexical resource, Wordnet.
# - WordNetLemmatizer is majorly used to build a vocabulary of words, which are valid Lemmas.

# %%
wnl = nltk.WordNetLemmatizer()

# %%
wnl_stem_words = [wnl.lemmatize(word) for word in set(lc_words) ]

# %%
len(set(wnl_stem_words))
# Out:
# 15168

# %%
from nltk.corpus import brown

# %%
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
humor_words = brown.words(categories='humor')

# %%
lc_humor_words = [word.lower() for word in humor_words]

# %%
lc_humor_uniq_words = list(set(lc_humor_words))

# %%
lc_humor_uniq_words
# Out:
# ['profound',
#  'courtiers',
#  'cup',
#  'victory',
#  'frozen',
#  'feeley',
#  'oscar',
#  'secured',
#  'change',
#  'dictum',
#  'blind',
#  'apartment',
#  'perle',
#  'escaped',
#  'tells',
#  "wife's",
#  'winked',
#  'charming',
#  "clergyman's",
#  'contributes',
#  'silent',
#  'excess',
#  'sung',
#  'forecast',
#  'lists',
#  'secretly',
#  'curio',
#  'commoners',
#  'uniformed',
#  'jeunes',
#  'culmination',
#  'their',
#  'violently',
#  'read',
#  'free',
#  'salary',
#  'paid',
#  'hope',
#  'probably',
#  'my',
#  'downfall',
#  'touch',
#  'apparent',
#  'pattern',
#  'admit',
#  'mighty',
#  'saner',
#  'los',
#  'himself',
#  'scandal',
#  'babylon',
#  'comfortably',
#  'metal',
#  'maltreat',
#  'focused',
#  'wynn',
#  'tries',
#  'modern',
#  'trump',
#  'parent',
#  'low',
#  'presently',
#  'aviary',
#  'during',
#  "carpenter's",
#  'remarks',
#  'threw',
#  'roles',
#  'inches',
#  'understand',
#  "it's",
#  'comprehend',
#  'lifelong',
#  'ready',
#  'glad',
#  'relentlessness',
#  'acts',
#  'carvings',
#  'filling',
#  'gooshey',
#  'jumpy',
#  'stems',
#  'bothering',
#  'cowardice',
#  'pages',
#  'beaches',
#  'floor',
#  'serving',
#  'needless',
#  'seems',
#  'spot',
#  'presidential',
#  "'",
#  'portant',
#  'shouted',
#  'suggested',
#  'pangs',
#  'quickly',
#  'revelation',
#  'o',
#  'noel',
#  'days',
#  'cortege',
#  'persona',
#  'after',
#  'ladle',
#  'growing',
#  'abundance',
#  'brown',
#  'clinked',
#  'vignette',
#  'seemed',
#  'questioning',
#  'thing',
#  'dull',
#  'wore',
#  'awhile',
#  'stage',
#  'president',
#  'anybody',
#  'slip',
#  'chalmers',
#  'tap',
#  'imperialism',
#  'dunkirk',
#  'arrived',
#  'literary',
#  'bee',
#  'tragically',
#  'drawers',
#  'speech',
#  'mystery',
#  'gwen',
#  'panels',
#  'hubris',
#  'competently',
#  'colonial',
#  'schooldays',
#  'troubles',
#  'part',
#  'lammed',
#  "he's",
#  'bushes',
#  'loved',
#  'rain',
#  'rajah',
#  'committees',
#  'suburbia',
#  'clear',
#  'gadgets',
#  'ordinarily',
#  'khmer',
#  'philosophic',
#  'revulsion',
#  'whosoever',
#  "there'll",
#  'standard',
#  'compassionately',
#  'react',
#  'seeing',
#  'unlikely',
#  'listed',
#  'agony',
#  'murders',
#  'meaningless',
#  'beyond',
#  'magnificent',
#  'knowing',
#  'smoke',
#  'correspondence',
#  'tremendously',
#  'breaking',
#  'arlene',
#  'draw',
#  'hastening',
#  'withhold',
#  'enrico',
#  'losses',
#  'perelman',
#  "longfellow's",
#  'doctor',
#  'fing',
#  'meet',
#  'horror',
#  'crisscrossed',
#  'salamander',
#  'repeated',
#  'fifty',
#  'shows',
#  'authentic',
#  'chinese',
#  'exasperate',
#  'warmth',
#  'merely',
#  'cracked',
#  'provocative',
#  'reflexes',
#  'allah',
#  'escape',
#  'clouds',
#  'circulation',
#  'shapeless',
#  'how',
#  'forgive',
#  'dozen',
#  'bout-de-souffle',
#  'remotely',
#  'patronizing',
#  'sitter',
#  'warm-up',
#  'regiment',
#  'paraphrasing',
#  'atkinson',
#  'suppose',
#  'coward',
#  'pause',
#  'america',
#  'specifications',
#  'dilys',
#  'unearthed',
#  'tongue',
#  'subscription',
#  'affair',
#  'reminiscent',
#  'telephone',
#  'lead',
#  'camp',
#  'personalities',
#  'clapping',
#  'passed',
#  'layman',
#  'tell',
#  'french',
#  "dell'",
#  "won't",
#  'any',
#  'positively',
#  'conscientious',
#  'grimly',
#  'commenting',
#  'hubba',
#  'attitude',
#  '7:30',
#  'doug',
#  'emerson',
#  'badly',
#  'murdering',
#  'applejack',
#  'dilemma',
#  'restively',
#  'sticking',
#  'producer',
#  'crawl',
#  'remembered',
#  'ceaseless',
#  'shown',
#  'yellow',
#  'only',
#  'cattle',
#  'following',
#  'beds',
#  'propose',
#  'suburban',
#  'petite',
#  'regarding',
#  'preserve',
#  'snoop',
#  'refers',
#  'decadent',
#  'warehouse',
#  'sweet',
#  'showed',
#  'measurable',
#  'screw',
#  'phrases',
#  'sired',
#  'ought',
#  'baroness',
#  'hoping',
#  'accurately',
#  'ever',
#  'impatiently',
#  'goddess',
#  'ambiguity',
#  'position',
#  'conversation',
#  'burglars',
#  'bosses',
#  'plow',
#  "world's",
#  'del',
#  'seeks',
#  'prohibitive',
#  'might',
#  'identified',
#  "policeman's",
#  'mrs.',
#  'chiseled',
#  'each',
#  'unparalleled',
#  'brinsley',
#  'bouanahsha',
#  'shooting',
#  'shook',
#  'icing',
#  'song',
#  'help',
#  'wiggled',
#  'whereupon',
#  'remarking',
#  'painting',
#  'full',
#  'jocose',
#  'species',
#  'fluke',
#  'unison',
#  'began',
#  'colors',
#  'l.',
#  'express',
#  'gambling',
#  'three',
#  'course',
#  'wagon',
#  'barco',
#  'hot-shot',
#  'objets',
#  'rummaging',
#  'pretending',
#  'gasse',
#  'item',
#  'centers',
#  'jones',
#  'verbal',
#  'marriage',
#  'rackets',
#  'common',
#  'whispered',
#  'meant',
#  'barrymores',
#  'sweeping',
#  'studio',
#  'unexpectedly',
#  'aspirations',
#  'pressures',
#  'bottle',
#  'comfortable',
#  'prelude',
#  'slammed',
#  'daring',
#  'albert',
#  'ape',
#  'whose',
#  'herb',
#  'natives',
#  'sink',
#  'paying',
#  'throne',
#  'parties',
#  'age',
#  'find',
#  'cheekbones',
#  'reduced',
#  'former',
#  'wide',
#  'brothel',
#  'sophisticates',
#  '!',
#  'smoking',
#  'ashamed',
#  'again',
#  'describes',
#  'arts',
#  'african',
#  'thinking',
#  'angry',
#  'meredith',
#  'loathsome',
#  'window',
#  'hot-slough',
#  'mama',
#  'loaded',
#  'believes',
#  'existentialist',
#  'blissfully',
#  'result',
#  'urged',
#  'stupefying',
#  'bound',
#  'elysees',
#  'desire',
#  'ba-a-a',
#  'behind',
#  'controversial',
#  'discipline',
#  'catch',
#  'noble',
#  'upside',
#  'cake',
#  'anywhere',
#  'journalese',
#  'fix',
#  'intimate',
#  'california',
#  'pulova',
#  'allusion',
#  'indian',
#  'stiff',
#  'wrecked',
#  'order',
#  'said',
#  'drastically',
#  'considerately',
#  'recount',
#  'despoiling',
#  'effect',
#  "hadn't",
#  'worm',
#  'enjoy',
#  'bogartian',
#  'fruit',
#  'advertised',
#  'lot',
#  'anatomicals',
#  'finish',
#  'usual',
#  'launched',
#  'unoccupied',
#  'manage',
#  'less',
#  'quality',
#  'riddling',
#  'timber',
#  'contraptions',
#  'minds',
#  'nice',
#  'inseparable',
#  'poised',
#  'cigarettes',
#  'unless',
#  'efficient',
#  'academic',
#  'just',
#  'toes',
#  'round',
#  'canvas',
#  'crime',
#  'fork',
#  'hopeless',
#  'hobby',
#  'albany',
#  'gingerly',
#  'driver',
#  'vote',
#  'damned',
#  'extent',
#  'equal',
#  'sting',
#  'portion',
#  'rude',
#  'tossed',
#  'affianced',
#  'modifiers',
#  'cigar',
#  'abstract',
#  'relief',
#  'usually',
#  'yvette',
#  'sport',
#  'catatonia',
#  'fancy',
#  'scimitar',
#  'dining',
#  'nights',
#  'rods',
#  'heaven',
#  'unfortunately',
#  'commiserate',
#  'diminishing',
#  'seriously',
#  'eyes',
#  'greedy',
#  'founded',
#  'historic',
#  'angst',
#  're-explore',
#  'rhinoceros',
#  'tracked',
#  'refuge',
#  'saint',
#  'impeccable',
#  'vase',
#  'admired',
#  'interlude',
#  'i.e.',
#  'guessed',
#  'sirs',
#  'committed',
#  'dashing',
#  'light',
#  'husband',
#  'family',
#  'cycle',
#  'treacherous',
#  'explicit',
#  'clergymen',
#  'viola',
#  'scarify',
#  'yorker',
#  'limitations',
#  'dawn',
#  "flynn's",
#  'diary',
#  'single-handedly',
#  'therein',
#  'victim',
#  'band',
#  'plumbed',
#  'alps',
#  'years',
#  'proportions',
#  'daphne',
#  'another',
#  'cocu',
#  'jews',
#  'bittersweet',
#  "host's",
#  'broken',
#  'ego',
#  'spotlight',
#  'sing',
#  'letter',
#  'search',
#  'leaned',
#  'aware',
#  'interviewer',
#  'funeral',
#  'chipping',
#  'developed',
#  'single',
#  "fran's",
#  'placed',
#  'chairmen',
#  'gracious',
#  'collector',
#  'away',
#  'proceeded',
#  'inspirational',
#  'hundred',
#  'coldness',
#  'guilt',
#  'threat',
#  "couldn't",
#  'off',
#  'herald',
#  'exclusive',
#  'artists',
#  'rubbish',
#  'slat',
#  'beset',
#  'italian',
#  'chaperon',
#  'off-duty',
#  'possess',
#  'generally',
#  'crippling',
#  'persuaded',
#  'husbands',
#  'rest',
#  'mouthpiece',
#  'heiress',
#  'ambiguities',
#  'solar',
#  'province',
#  'illustrate',
#  'furniture',
#  'world',
#  'seconds',
#  'wait',
#  'strength',
#  'greater',
#  'safe',
#  'efforts',
#  'attempts',
#  'future',
#  'independence',
#  'completed',
#  'serious',
#  'committee',
#  'ambition',
#  'chance',
#  'means',
#  'potatoes',
#  'deep',
#  'kafka',
#  'costly',
#  'misdirectors',
#  'invitation',
#  'non-readers',
#  'crannies',
#  'shoulders',
#  'bureaus',
#  'hair',
#  'flautist',
#  "there's",
#  'reward',
#  'verse',
#  'misunderstanders',
#  'although',
#  'nettled',
#  'tutor',
#  'hex',
#  'rhetoricians',
#  'paso',
#  'woke',
#  'empty',
#  'ivory',
#  'style',
#  'frontier',
#  'farmed',
#  'forum',
#  'expecting',
#  'enfant',
#  'krishna',
#  'lawn',
#  "reader's",
#  'digest',
#  'smashed',
#  'mailer',
#  "an'",
#  'suicide',
#  'gotten',
#  'couple',
#  'fairy-tale',
#  'concede',
#  'presentation',
#  'especially',
#  'tragedies',
#  'cereal',
#  'contentedly',
#  'becomes',
#  'notoriety',
#  'teetotaler',
#  'known',
#  'truck',
#  'artistic',
#  'simpler',
#  'romance',
#  'refer',
#  'statuette',
#  'arose',
#  'absorb',
#  'blink',
#  'hardly',
#  'visiting',
#  'length',
#  'youngest',
#  'san',
#  'yet',
#  'thespians',
#  'studied',
#  'officials',
#  'bulwark',
#  'colmans',
#  'use',
#  'nervous',
#  'around',
#  'acid',
#  'dishes',
#  'cardinal',
#  'glint',
#  'unfavorable',
#  "we're",
#  'f.d.r.',
#  'doubt',
#  'bathtubs',
#  'balkiness',
#  'overcame',
#  'budweisers',
#  'bach',
#  'train',
#  'outfit',
#  'wanted',
#  'pwa',
#  'matter',
#  'sandpaper',
#  'obviously',
#  'sensitivity',
#  'wish',
#  'ah',
#  'rob',
#  "opera's",
#  'errol',
#  'shelves',
#  'forever',
#  'coconut-containing',
#  'overtake',
#  'accepted',
#  'monet',
#  'mr.',
#  'box',
#  'joke',
#  'dance',
#  'lean',
#  'ben',
#  'hand',
#  'availed',
#  'vulnerable',
#  'overture',
#  'carthago',
#  'breach',
#  'entered',
#  'more',
#  'glendale',
#  'brought',
#  'protested',
#  'speed',
#  'kicking',
#  'yearly',
#  'money',
#  'ideologist',
#  'tonight',
#  'wherever',
#  'shipshape',
#  'quantity',
#  'tasteless',
#  'rosy',
#  'creditable',
#  'shoestring',
#  'profanity',
#  'university',
#  'cause',
#  'normal',
#  'debutante',
#  'agreements',
#  'consideration',
#  'mice',
#  'inspection',
#  'bear',
#  'tribunal',
#  'but',
#  'felix',
#  'gadget',
#  "pockmanster's",
#  'walk',
#  'rapidly',
#  'everybody',
#  'spectacularly',
#  'russians',
#  'dearly',
#  'among',
#  'rested',
#  'misconstructions',
#  'filmdom',
#  'punishing',
#  'imploring',
#  'occupant',
#  'crazy',
#  'foot',
#  'offbeat',
#  'not',
#  'drinking',
#  'pacing',
#  'gulp',
#  'restricted',
#  'cooking',
#  'be',
#  'inexplicable',
#  'thereupon',
#  'lucky',
#  'principal',
#  'dustbin',
#  'onto',
#  'on',
#  'bent',
#  'chi-chi',
#  'purchased',
#  'pip',
#  'retribution',
#  'music',
#  'irritable',
#  'facts',
#  'exact',
#  'masterpiece',
#  'so-called',
#  'talked',
#  'human',
#  'quarter-century',
#  'often',
#  'drib-drool',
#  'outer',
#  'pocket',
#  'beneath',
#  'similarly',
#  'jokers',
#  'modifier',
#  'jaded',
#  'performance',
#  'all-pervading',
#  'tooling',
#  'vocation',
#  'derision',
#  'heisted',
#  'responded',
#  'car',
#  'demonstrable',
#  'pawnshop',
#  'over',
#  'tailor',
#  'home',
#  'clutched',
#  'drink',
#  'joy',
#  'mile',
#  'non-color',
#  'ground',
#  'yapping',
#  'fran',
#  'trip',
#  'metronome',
#  'motionless',
#  'reverence',
#  'tremendous',
#  'list',
#  'own',
#  'cooked',
#  'larceny',
#  'variety',
#  'patients',
#  'ten',
#  'simplest',
#  'small',
#  'wpa',
#  'devotion',
#  'upset',
#  'coercion',
#  'region',
#  'warm',
#  'compound',
#  'doll',
#  'episode',
#  'puts',
#  'alexander',
#  'litigant',
#  'worshiped',
#  'mason',
#  'torment',
#  'murder',
#  "cook's",
#  'that',
#  'day',
#  'repetition',
#  'entitle',
#  'dunes',
#  'slips',
#  'tongue-twister',
#  'banana',
#  'unfunny',
#  'resumed',
#  "isn't",
#  'indelible',
#  'run',
#  "quasimodo's",
#  'bookies',
#  'gets',
#  'distant',
#  'century',
#  'cahoots',
#  'priests',
#  'specialists',
#  'belly',
#  'outspoken',
#  'turn',
#  'awaiting',
#  'explanatory',
#  'remains',
#  "mother's",
#  'dial',
#  'leftist',
#  'many',
#  'distinguished',
#  'divinity',
#  "roylott's",
#  'taste',
#  'continues',
#  'dragged',
#  'festival',
#  'fourteen',
#  'practices',
#  'task',
#  'armadillo',
#  'trite',
#  'stranger',
#  'set',
#  'cynics',
#  'headlinese',
#  'disbelieves',
#  'precocious',
#  'gird',
#  'interpreter',
#  'stick',
#  'conducive',
#  'clarity',
#  'unconstitutional',
#  'collapse',
#  'included',
#  'madam',
#  'starts',
#  'pamper',
#  'finances',
#  'laughed',
#  'existence',
#  "we've",
#  'cultist',
#  'salivate',
#  'observe',
#  'noted',
#  'household',
#  'lived',
#  'end',
#  'jest',
#  'movement',
#  'moral',
#  'records',
#  'plan',
#  'twenty-five',
#  'rushed',
#  'inherited',
#  'fog',
#  'oil',
#  'passage',
#  'park',
#  'cracks',
#  'think',
#  'citizen',
#  'overreached',
#  'to',
#  'carried',
#  'completing',
#  'amulet',
#  'lay',
#  'mask',
#  'frambesia',
#  'americans',
#  'considered',
#  'party',
#  'inquired',
#  'hard',
#  'dignity',
#  'habitat',
#  'housebreakers',
#  'habit',
#  'at',
#  'arranged',
#  'damn',
#  'cartoon',
#  'kinds',
#  'willing',
#  'meaning',
#  'upstairs',
#  'sacred',
#  'est',
#  'commotion',
#  'nonconformist',
#  'pot',
#  'blonde',
#  'bronx',
#  'soon',
#  'swatches',
#  'says',
#  'move',
#  'wild',
#  'gorshek',
#  'footwear',
#  'stuck',
#  'jade-handled',
#  'epicure',
#  'cards',
#  'sarcastic',
#  "moore's",
#  'catharsis',
#  'where',
#  'mercenaries',
#  'chancellor',
#  'notice',
#  'swift',
#  'upon',
#  'you',
#  'statue',
#  'terrifying',
#  'crawled',
#  'dominated',
#  'luckier',
#  'threats',
#  'humanity',
#  'phone',
#  "conductor's",
#  'bambi',
#  'laughingly',
#  'nebraska',
#  ...]

# %%
from nltk.corpus import words

# %%
wordlist_words = words.words()

# %%
wordlist_uniq_words = list(set(wordlist_words))

# %%
print(lc_humor_uniq_words)
# Out:
# ['profound', 'courtiers', 'cup', 'victory', 'frozen', 'feeley', 'oscar', 'secured', 'change', 'dictum', 'blind', 'apartment', 'perle', 'escaped', 'tells', "wife's", 'winked', 'charming', "clergyman's", 'contributes', 'silent', 'excess', 'sung', 'forecast', 'lists', 'secretly', 'curio', 'commoners', 'uniformed', 'jeunes', 'culmination', 'their', 'violently', 'read', 'free', 'salary', 'paid', 'hope', 'probably', 'my', 'downfall', 'touch', 'apparent', 'pattern', 'admit', 'mighty', 'saner', 'los', 'himself', 'scandal', 'babylon', 'comfortably', 'metal', 'maltreat', 'focused', 'wynn', 'tries', 'modern', 'trump', 'parent', 'low', 'presently', 'aviary', 'during', "carpenter's", 'remarks', 'threw', 'roles', 'inches', 'understand', "it's", 'comprehend', 'lifelong', 'ready', 'glad', 'relentlessness', 'acts', 'carvings', 'filling', 'gooshey', 'jumpy', 'stems', 'bothering', 'cowardice', 'pages', 'beaches', 'floor', 'serving', 'needless', 'seems', 'spot', 'presidential', "'", 'portant', 'shouted', 'suggested', 'pangs', 'quickly', 'revelation', 'o', 'noel', 'days', 'cortege', 'persona', 'after', 'ladle', 'growing', 'abundance', 'brown', 'clinked', 'vignette', 'seemed', 'questioning', 'thing', 'dull', 'wore', 'awhile', 'stage', 'president', 'anybody', 'slip', 'chalmers', 'tap', 'imperialism', 'dunkirk', 'arrived', 'literary', 'bee', 'tragically', 'drawers', 'speech', 'mystery', 'gwen', 'panels', 'hubris', 'competently', 'colonial', 'schooldays', 'troubles', 'part', 'lammed', "he's", 'bushes', 'loved', 'rain', 'rajah', 'committees', 'suburbia', 'clear', 'gadgets', 'ordinarily', 'khmer', 'philosophic', 'revulsion', 'whosoever', "there'll", 'standard', 'compassionately', 'react', 'seeing', 'unlikely', 'listed', 'agony', 'murders', 'meaningless', 'beyond', 'magnificent', 'knowing', 'smoke', 'correspondence', 'tremendously', 'breaking', 'arlene', 'draw', 'hastening', 'withhold', 'enrico', 'losses', 'perelman', "longfellow's", 'doctor', 'fing', 'meet', 'horror', 'crisscrossed', 'salamander', 'repeated', 'fifty', 'shows', 'authentic', 'chinese', 'exasperate', 'warmth', 'merely', 'cracked', 'provocative', 'reflexes', 'allah', 'escape', 'clouds', 'circulation', 'shapeless', 'how', 'forgive', 'dozen', 'bout-de-souffle', 'remotely', 'patronizing', 'sitter', 'warm-up', 'regiment', 'paraphrasing', 'atkinson', 'suppose', 'coward', 'pause', 'america', 'specifications', 'dilys', 'unearthed', 'tongue', 'subscription', 'affair', 'reminiscent', 'telephone', 'lead', 'camp', 'personalities', 'clapping', 'passed', 'layman', 'tell', 'french', "dell'", "won't", 'any', 'positively', 'conscientious', 'grimly', 'commenting', 'hubba', 'attitude', '7:30', 'doug', 'emerson', 'badly', 'murdering', 'applejack', 'dilemma', 'restively', 'sticking', 'producer', 'crawl', 'remembered', 'ceaseless', 'shown', 'yellow', 'only', 'cattle', 'following', 'beds', 'propose', 'suburban', 'petite', 'regarding', 'preserve', 'snoop', 'refers', 'decadent', 'warehouse', 'sweet', 'showed', 'measurable', 'screw', 'phrases', 'sired', 'ought', 'baroness', 'hoping', 'accurately', 'ever', 'impatiently', 'goddess', 'ambiguity', 'position', 'conversation', 'burglars', 'bosses', 'plow', "world's", 'del', 'seeks', 'prohibitive', 'might', 'identified', "policeman's", 'mrs.', 'chiseled', 'each', 'unparalleled', 'brinsley', 'bouanahsha', 'shooting', 'shook', 'icing', 'song', 'help', 'wiggled', 'whereupon', 'remarking', 'painting', 'full', 'jocose', 'species', 'fluke', 'unison', 'began', 'colors', 'l.', 'express', 'gambling', 'three', 'course', 'wagon', 'barco', 'hot-shot', 'objets', 'rummaging', 'pretending', 'gasse', 'item', 'centers', 'jones', 'verbal', 'marriage', 'rackets', 'common', 'whispered', 'meant', 'barrymores', 'sweeping', 'studio', 'unexpectedly', 'aspirations', 'pressures', 'bottle', 'comfortable', 'prelude', 'slammed', 'daring', 'albert', 'ape', 'whose', 'herb', 'natives', 'sink', 'paying', 'throne', 'parties', 'age', 'find', 'cheekbones', 'reduced', 'former', 'wide', 'brothel', 'sophistica ...

# %%
print(wordlist_uniq_words)
# Out:
# 235892
