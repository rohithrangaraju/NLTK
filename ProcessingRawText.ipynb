# %%
from urllib import request

# %%
url = "http://www.gutenberg.org/files/2554/2554-0.txt"

# %%
html_content = request.urlopen(url).read()

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
inner_body = soup.find_all('div', attrs={'class':'story-body__inner'})

inner_text = [elm.text for elm in inner_body[0].find_all(['h1', 'h2', 'p', 'li']) ]
 
text_content2 = '\n'.join(inner_text)

# %%
inner_body
# Out:
# []

# %%
import nltk

# %%
nltk.word_tokenize("Python is cool!!!")
# Out:
# ['Python', 'is', 'cool', '!', '!', '!']

# %%
import re

# %%
word=nltk.regexp_tokenize("Python is cool!!!",r'\w+')

# %%
print(word)
# Out:
# ['Python', 'is', 'cool']

# %%
from urllib import request
url1 = "https://en.wikipedia.org/wiki/Python_(programming_language)"
import ssl

# This restores the same behavior as before.
context = ssl._create_unverified_context()
html_content = request.urlopen(url1, context=context).read()
soup = BeautifulSoup(html_content, 'html.parser')

n_links = [link['href']for link in soup.findAll('a', href=True)]
print(n_links)
# Out:
# ['/wiki/Wikipedia:Good_articles', '/wiki/Wikipedia:Protection_policy#semi', '#mw-head', '#p-search', '/wiki/File:Python_logo_and_wordmark.svg', '/wiki/Programming_paradigm', '/wiki/Object-oriented_programming', '/wiki/Imperative_programming', '/wiki/Functional_programming', '/wiki/Procedural_programming', '/wiki/Reflective_programming', '/wiki/Software_design', '/wiki/Guido_van_Rossum', '/wiki/Software_developer', '/wiki/Python_Software_Foundation', '#cite_note-guttag-1', '/wiki/Software_release_life_cycle', '#cite_note-2', '#cite_note-3', '/wiki/Type_system', '/wiki/Duck_typing', '/wiki/Dynamic_typing', '/wiki/Strong_typing', '/wiki/Gradual_typing', '#cite_note-4', '/wiki/Software_license', '/wiki/Python_Software_Foundation_License', '/wiki/Filename_extension', '#cite_note-5', '#cite_note-6', 'https://www.python.org/', '/wiki/Programming_language_implementation', '/wiki/CPython', '/wiki/IronPython', '/wiki/Jython', '/wiki/MicroPython', '/wiki/Numba', '/wiki/PyPy', '/wiki/Stackless_P
# ...

# %% [markdown]
# Hi, I have working on "NLP with Python" course in frescoplay. I have completed the assignment and everything. But there are some hands-on sessions in course which i need to complete. So there is some issue at frescoplay. For a particular hands-on session. There were some tasks i need to complete to complete the handson. But when i complete the task i am unable to complete the handson. Its asking me to the complete the task. Below are the course details.
#
# Digital : NLP Using Python_FP
# ID:56711
